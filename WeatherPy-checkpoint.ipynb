# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from api_keys import api_key
   
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

output_data_file = "cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %%
baseurl = "http://api.openweathermap.org/data/2.5/weather?"
url = baseurl + "AppId=" + api_key + "&q="

City= []
Cloudiness= []
Country= []
Date= []
Humidity= []
Lat = []
Lng = []
MaxTemp = []
WindSpeed = []

for city in cities:
    response = requests.get(url + city).json()
    try:
        City.append(response['name'])
        Cloudiness.append(response['clouds']['all'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        MaxTemp.append(response['main']['temp_max'])
        WindSpeed.append(response['wind']['speed'])
    except:
        print(f'skipping {city}')
# Out:
# skipping amderma
# skipping vaitupu
# skipping belushya guba
# skipping taolanaro
# skipping mys shmidta
# skipping grand river south east
# skipping cozumel
# skipping taburi
# skipping nizhneyansk
# skipping barentsburg
# skipping palabuhanratu
# skipping sentyabrskiy
# skipping samusu
# skipping barawe
# skipping waw
# skipping tumannyy
# skipping alotau
# skipping achisay
# skipping illoqqortoormiut
# skipping ust-kamchatsk
# skipping rungata
# skipping khonuu
# skipping acarau
# skipping marcona
# skipping naftah
# skipping mrirt
# skipping samalaeulu
# skipping usevya
# skipping bengkulu
# skipping bolungarvik
# skipping louisbourg
# skipping attawapiskat
# skipping sakakah
# skipping haibowan
# skipping bolshoy tsaryn
# skipping saleaula
# skipping ozgon
# skipping tsihombe
# skipping chagda
# skipping umzimvubu
# skipping saryshagan
# skipping olafsvik
# skipping skagastrond
# skipping kyra
# skipping toliary
# skipping sorvag
# skipping litoral del san juan
# ...

# %%
weather_dict = {
    "City": City,
    "Cloudiness": Cloudiness,
    "Country": Country,
    "Date": Date,
    "Humidity": Humidity,
    "Lat": Lat,
    "Lng": Lng,
    "Max Temp": MaxTemp,
    "Wind Speed": WindSpeed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
weather_data.to_csv("weather_data.csv")

# %%
weather_data.count()
# Out:
# City          544
# Cloudiness    544
# Country       544
# Date          544
# Humidity      544
# Lat           544
# Lng           544
# Max Temp      544
# Wind Speed    544
# dtype: int64

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", facecolors="pink", edgecolors="black", alpha=0.75)

plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.title("City Latitude vs. Temperature(07/11/2019)")
plt.grid()
plt.tight_layout()
plt.savefig("lat_temp.png")
plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", facecolors="pink", edgecolors="black", alpha=0.75)

plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title("City Latitude vs. Humidity(07/11/2019)")
plt.grid()
plt.tight_layout()
plt.savefig("lat_humidity.png")
plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", facecolors="pink", edgecolors="black", alpha=0.75)

plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title("City Latitude vs. Cloudiness(07/11/2019)")
plt.grid()
plt.tight_layout()
plt.savefig("lat_cloud.png")
plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", facecolors="pink", edgecolors="black", alpha=0.75)

plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.title("City Latitude vs. Wind Speed(07/11/2019)")
plt.grid()
plt.tight_layout()
plt.savefig("lat_wind.png")
plt.show()
